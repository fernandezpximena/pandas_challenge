# %%
import pandas as pd
import numpy as np

# %%
pymoli = pd.read_csv("purchase_data.csv")
pymoli.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
pymoli.describe ()
# Out:
#        Purchase ID         Age     Item ID       Price
# count   780.000000  780.000000  780.000000  780.000000
# mean    389.500000   22.714103   92.114103    3.050987
# std     225.310896    6.659444   52.775943    1.169549
# min       0.000000    7.000000    0.000000    1.000000
# 25%     194.750000   20.000000   48.000000    1.980000
# 50%     389.500000   22.000000   93.000000    3.150000
# 75%     584.250000   25.000000  139.000000    4.080000
# max     779.000000   45.000000  183.000000    4.990000

# %%
count= pymoli ["SN"].value_counts()
count
# Out:
# Lisosia93       5
# Idastidru52     4
# Iral74          4
# Haillyrgue51    3
# Ilarin91        3
#                ..
# Frichaya88      1
# Jiskadarst60    1
# Iduenu77        1
# Undassa89       1
# Quaranmol58     1
# Name: SN, Length: 576, dtype: int64

# %%
unique = pymoli ["Item ID"].unique()
unique
# Out:
# array([108, 143,  92, 100, 131,  81, 169, 162,  21, 136,  95, 116,   4,
#        165,  98,  40, 161,  82,  89,  57, 168,  24, 151, 141, 178,  71,
#         96, 119,  37, 140, 179, 133,  44, 160,  53,  76,  73, 172,   7,
#         72,   9, 181, 102, 170, 138, 110,  22,  15,  60, 176,  25,  84,
#         80, 152, 105, 125,  56,  34,   6,  27,  29,  68, 124,  88,  20,
#         50, 174,  12,  33, 129,  17,  59,  39, 164, 134, 101, 109,  10,
#         54,  99,  85, 139,  41, 150,  13, 117,  78,  87,   1,  62,  75,
#         58,  74, 120, 145,   0,   2, 146, 158,   8, 175,  46, 148, 111,
#          3,  65, 183,  30, 157, 123,   5, 144, 103, 135,  51, 154,  32,
#         77,  11,  63,  69, 113, 153, 114, 149, 159, 137, 142,  66,  97,
#        163, 107,  16,  42,  19,  83,  23,  28,  94, 182,  70,  18, 166,
#        173, 167, 155, 128, 156, 147,  35, 171,  52, 106,  38,  91, 118,
#         67,  45,  49, 121,  79,  14,  43,  31,  64,  86,  93,  26, 122,
# ...

# %%
average_price= pymoli["Price"].mean()
average_price
# Out:
# 3.050987179487176

# %%
total_purchase_count= pymoli ["Purchase ID"].value_counts()
total_purchase_count
# Out:
# 779    1
# 243    1
# 265    1
# 264    1
# 263    1
#       ..
# 517    1
# 516    1
# 515    1
# 514    1
# 0      1
# Name: Purchase ID, Length: 780, dtype: int64

# %%
total_revenue= pymoli ["Price"].sum()
total_revenue
# Out:
# 2379.77

# %%
count_gender= pymoli ["Gender"].value_counts()
count_gender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
sum_gender= count_gender.sum()
sum_gender
# Out:
# 780

# %%
counts = pymoli["Gender"].value_counts()
percent = pymoli["Gender"].value_counts(normalize=True)
percent100 = pymoli["Gender"] .value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#                        counts       per per100
# Male                      652  0.835897  83.6%
# Female                    113  0.144872  14.5%
# Other / Non-Disclosed      15  0.019231   1.9%

# %%
gender_stats = pymoli.groupby(["Gender"])
gender_stats.count().head()
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
gender_stats = pymoli.groupby(["Gender"])
gender_stats.mean().head()
# Out:
#                        Purchase ID        Age    Item ID     Price
# Gender
# Female                  379.380531  21.345133  85.477876  3.203009
# Male                    392.516871  22.917178  93.524540  3.017853
# Other / Non-Disclosed   334.600000  24.200000  80.800000  3.346000

# %%
gender_stats = pymoli.groupby(["Gender"])
gender_stats.sum().head()
# Out:
#                        Purchase ID    Age  Item ID    Price
# Gender
# Female                       42870   2412     9659   361.94
# Male                        255921  14942    60978  1967.64
# Other / Non-Disclosed         5019    363     1212    50.19

# %%
age_stats_count = pymoli.groupby(["Age"])
age_stats_count.count().head()
# Out:
#      Purchase ID  SN  Gender  Item ID  Item Name  Price
# Age
# 7              9   9       9        9          9      9
# 8              8   8       8        8          8      8
# 9              6   6       6        6          6      6
# 10             9   9       9        9          9      9
# 11             7   7       7        7          7      7

# %%
bin= [-1,14,19,20]
bin_names= [">10","10-14","15-19", "<20"]

# %%
df = pd.DataFrame(age_stats_count)
df
# Out:
#      0                                                  1
# 0    7       Purchase ID             SN  Age  Gender  ...
# 1    8       Purchase ID            SN  Age  Gender  I...
# 2    9       Purchase ID            SN  Age Gender  It...
# 3   10       Purchase ID          SN  Age  Gender  Ite...
# 4   11       Purchase ID           SN  Age Gender  Ite...
# 5   12       Purchase ID             SN  Age Gender  I...
# 6   13       Purchase ID            SN  Age  Gender  I...
# 7   14       Purchase ID             SN  Age Gender  I...
# 8   15       Purchase ID             SN  Age          ...
# 9   16       Purchase ID               SN  Age        ...
# 10  17       Purchase ID             SN  Age  Gender  ...
# 11  18       Purchase ID             SN  Age  Gender  ...
# 12  19       Purchase ID              SN  Age  Gender ...
# 13  20       Purchase ID             SN  Age Gender  I...
# 14  21       Purchase ID            SN  Age  Gender  I...
# ...

# %%
pymoli.sort_values(['Item ID', 'Item Name','Purchase ID', 'Price'], ascending=False).groupby('Item ID').head()
# Out:
#      Purchase ID          SN  Age  Gender  Item ID            Item Name  Price
# 705          705   Aelidru27   22    Male      183  Dragon's Greatsword   1.09
# 618          618  Aisurdru79   29  Female      183  Dragon's Greatsword   1.09
# 165          165  Lirtassa52   15    Male      183  Dragon's Greatsword   1.09
# 758          758      Iral74   21    Male      182            Toothpick   4.03
# 313          313   Iasrira89   23    Male      182            Toothpick   4.03
# ..           ...         ...  ...     ...      ...                  ...    ...
# 121          121    Ilosia37   23    Male        1             Crucifer   3.26
# 662          662  Mindilsa60   21    Male        0             Splinter   1.28
# 204          204  Chamimla85   16    Male        0             Splinter   1.28
# 150          150    Inasti31   17    Male        0             Splinter   1.28
# 133          133    Phaena87   20    Male        0             Splinter   1.28
#
# [697 rows x 7 columns]
